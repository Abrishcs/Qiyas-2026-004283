# %%
qiyas={"Qiyas-0123":
       {"family":[], "friends":[]}
      }
print(qiyas)
# Out:
# {'Qiyas-0123': {'family': [], 'friends': []}}

# %%
text="The internet has changed the way people learn and communicate. In the past, students had to spend many hours in libraries to find information for their homework. Today, people can search for knowledge online within seconds. Online classes also make education available to students who live far from schools and universities. Social media helps friends and families stay connected even when they are in different countries. However, the internet also has some disadvantages because people may spend too much time online. Some websites can spread false information very quickly. For this reason, users should learn how to check if information is true or not. Parents and teachers also need to guide young people in using technology wisely. When used correctly, the internet can improve education, communication, and daily life for millions of people around the world."
text.split()
# Out:
# ['The',
#  'internet',
#  'has',
#  'changed',
#  'the',
#  'way',
#  'people',
#  'learn',
#  'and',
#  'communicate.',
#  'In',
#  'the',
#  'past,',
#  'students',
#  'had',
#  'to',
#  'spend',
#  'many',
#  'hours',
#  'in',
#  'libraries',
#  'to',
#  'find',
#  'information',
#  'for',
#  'their',
#  'homework.',
#  'Today,',
#  'people',
#  'can',
#  'search',
#  'for',
#  'knowledge',
#  'online',
#  'within',
#  'seconds.',
#  'Online',
#  'classes',
#  'also',
#  'make',
#  'education',
#  'available',
#  'to',
#  'students',
#  'who',
#  'live',
#  'far',
#  'from',
#  'schools',
#  'and',
#  'universities.',
#  'Social',
#  'media',
#  'helps',
#  'friends',
#  'and',
#  'families',
#  'stay',
#  'connected',
#  'even',
#  'when',
#  'they',
#  'are',
#  'in',
#  'different',
#  'countries.',
#  'However,',
#  'the',
#  'internet',
#  'also',
#  'has',
#  'some',
#  'disadvantages',
#  'because',
#  'people',
#  'may',
#  'spend',
#  'too',
#  'much',
#  'time',
# ...

# %%
len(text.split())
# Out:
# 136

# %%
text = text.replace(",", "")
text = text.replace(".", "")

# %%
text
# Out:
# 'The internet has changed the way people learn and communicate In the past students had to spend many hours in libraries to find information for their homework Today people can search for knowledge online within seconds Online classes also make education available to students who live far from schools and universities Social media helps friends and families stay connected even when they are in different countries However the internet also has some disadvantages because people may spend too much time online Some websites can spread false information very quickly For this reason users should learn how to check if information is true or not Parents and teachers also need to guide young people in using technology wisely When used correctly the internet can improve education communication and daily life for millions of people around the world'

# %%
text.split()
# Out:
# ['The',
#  'internet',
#  'has',
#  'changed',
#  'the',
#  'way',
#  'people',
#  'learn',
#  'and',
#  'communicate',
#  'In',
#  'the',
#  'past',
#  'students',
#  'had',
#  'to',
#  'spend',
#  'many',
#  'hours',
#  'in',
#  'libraries',
#  'to',
#  'find',
#  'information',
#  'for',
#  'their',
#  'homework',
#  'Today',
#  'people',
#  'can',
#  'search',
#  'for',
#  'knowledge',
#  'online',
#  'within',
#  'seconds',
#  'Online',
#  'classes',
#  'also',
#  'make',
#  'education',
#  'available',
#  'to',
#  'students',
#  'who',
#  'live',
#  'far',
#  'from',
#  'schools',
#  'and',
#  'universities',
#  'Social',
#  'media',
#  'helps',
#  'friends',
#  'and',
#  'families',
#  'stay',
#  'connected',
#  'even',
#  'when',
#  'they',
#  'are',
#  'in',
#  'different',
#  'countries',
#  'However',
#  'the',
#  'internet',
#  'also',
#  'has',
#  'some',
#  'disadvantages',
#  'because',
#  'people',
#  'may',
#  'spend',
#  'too',
#  'much',
#  'time',
#  'online',
# ...

# %%
small=text.lower()
# Out:
# 'the internet has changed the way people learn and communicate. in the past, students had to spend many hours in libraries to find information for their homework. today, people can search for knowledge online within seconds. online classes also make education available to students who live far from schools and universities. social media helps friends and families stay connected even when they are in different countries. however, the internet also has some disadvantages because people may spend too much time online. some websites can spread false information very quickly. for this reason, users should learn how to check if information is true or not. parents and teachers also need to guide young people in using technology wisely. when used correctly, the internet can improve education, communication, and daily life for millions of people around the world.'

# %%
words=text.lower().split()

# %%
print(words)
# Out:
# ['the', 'internet', 'has', 'changed', 'the', 'way', 'people', 'learn', 'and', 'communicate.', 'in', 'the', 'past,', 'students', 'had', 'to', 'spend', 'many', 'hours', 'in', 'libraries', 'to', 'find', 'information', 'for', 'their', 'homework.', 'today,', 'people', 'can', 'search', 'for', 'knowledge', 'online', 'within', 'seconds.', 'online', 'classes', 'also', 'make', 'education', 'available', 'to', 'students', 'who', 'live', 'far', 'from', 'schools', 'and', 'universities.', 'social', 'media', 'helps', 'friends', 'and', 'families', 'stay', 'connected', 'even', 'when', 'they', 'are', 'in', 'different', 'countries.', 'however,', 'the', 'internet', 'also', 'has', 'some', 'disadvantages', 'because', 'people', 'may', 'spend', 'too', 'much', 'time', 'online.', 'some', 'websites', 'can', 'spread', 'false', 'information', 'very', 'quickly.', 'for', 'this', 'reason,', 'users', 'should', 'learn', 'how', 'to', 'check', 'if', 'information', 'is', 'true', 'or', 'not.', 'parents', 'and', 'teachers'
# ...

# %%
words.count("the")
# Out:
# 6

# %%
sorted(words)
# Out:
# ['also',
#  'also',
#  'also',
#  'and',
#  'and',
#  'and',
#  'and',
#  'and',
#  'are',
#  'around',
#  'available',
#  'because',
#  'can',
#  'can',
#  'can',
#  'changed',
#  'check',
#  'classes',
#  'communicate.',
#  'communication,',
#  'connected',
#  'correctly,',
#  'countries.',
#  'daily',
#  'different',
#  'disadvantages',
#  'education',
#  'education,',
#  'even',
#  'false',
#  'families',
#  'far',
#  'find',
#  'for',
#  'for',
#  'for',
#  'for',
#  'friends',
#  'from',
#  'guide',
#  'had',
#  'has',
#  'has',
#  'helps',
#  'homework.',
#  'hours',
#  'how',
#  'however,',
#  'if',
#  'improve',
#  'in',
#  'in',
#  'in',
#  'in',
#  'information',
#  'information',
#  'information',
#  'internet',
#  'internet',
#  'internet',
#  'is',
#  'knowledge',
#  'learn',
#  'learn',
#  'libraries',
#  'life',
#  'live',
#  'make',
#  'many',
#  'may',
#  'media',
#  'millions',
#  'much',
#  'need',
#  'not.',
#  'of',
#  'online',
#  'online',
#  'online.',
# ...

# %%
words.append("zapere")

# %%
words
# Out:
# ['the',
#  'internet',
#  'has',
#  'changed',
#  'the',
#  'way',
#  'people',
#  'learn',
#  'and',
#  'communicate.',
#  'in',
#  'the',
#  'past,',
#  'students',
#  'had',
#  'to',
#  'spend',
#  'many',
#  'hours',
#  'in',
#  'libraries',
#  'to',
#  'find',
#  'information',
#  'for',
#  'their',
#  'homework.',
#  'today,',
#  'people',
#  'can',
#  'search',
#  'for',
#  'knowledge',
#  'online',
#  'within',
#  'seconds.',
#  'online',
#  'classes',
#  'also',
#  'make',
#  'education',
#  'available',
#  'to',
#  'students',
#  'who',
#  'live',
#  'far',
#  'from',
#  'schools',
#  'and',
#  'universities.',
#  'social',
#  'media',
#  'helps',
#  'friends',
#  'and',
#  'families',
#  'stay',
#  'connected',
#  'even',
#  'when',
#  'they',
#  'are',
#  'in',
#  'different',
#  'countries.',
#  'however,',
#  'the',
#  'internet',
#  'also',
#  'has',
#  'some',
#  'disadvantages',
#  'because',
#  'people',
#  'may',
#  'spend',
#  'too',
#  'much',
#  'time',
# ...

# %%
word_count = {}

for word in words:
    if word in word_count:
        word_count[word] += 1
    else:
        word_count[word] = 1

print(word_count)
# Out:
# {'the': 6, 'internet': 3, 'has': 2, 'changed': 1, 'way': 1, 'people': 5, 'learn': 2, 'and': 5, 'communicate.': 1, 'in': 4, 'past,': 1, 'students': 2, 'had': 1, 'to': 5, 'spend': 2, 'many': 1, 'hours': 1, 'libraries': 1, 'find': 1, 'information': 3, 'for': 4, 'their': 1, 'homework.': 1, 'today,': 1, 'can': 3, 'search': 1, 'knowledge': 1, 'online': 2, 'within': 1, 'seconds.': 1, 'classes': 1, 'also': 3, 'make': 1, 'education': 1, 'available': 1, 'who': 1, 'live': 1, 'far': 1, 'from': 1, 'schools': 1, 'universities.': 1, 'social': 1, 'media': 1, 'helps': 1, 'friends': 1, 'families': 1, 'stay': 1, 'connected': 1, 'even': 1, 'when': 2, 'they': 1, 'are': 1, 'different': 1, 'countries.': 1, 'however,': 1, 'some': 2, 'disadvantages': 1, 'because': 1, 'may': 1, 'too': 1, 'much': 1, 'time': 1, 'online.': 1, 'websites': 1, 'spread': 1, 'false': 1, 'very': 1, 'quickly.': 1, 'this': 1, 'reason,': 1, 'users': 1, 'should': 1, 'how': 1, 'check': 1, 'if': 1, 'is': 1, 'true': 1, 'or': 1, 'not.': 1, 'p
# ...

# %%
import os

# %%
f = open("notes.txt", "a", encoding="utf-8")

f.write(f"{words}\n")
f.write(f"{words}\n")
f.close()

# %%
f = open("notes.txt", "r", encoding="utf-8")

print(f.read())

f.close()
# Out:
# Python is fun
# ...

# %%
f = open("notes.txt", "r", encoding="utf-8")

print(f.read())

f.close()
# Out:
# Python is fun
# ...
